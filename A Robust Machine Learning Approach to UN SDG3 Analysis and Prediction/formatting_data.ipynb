# %% [markdown]
# # Load The SDG3 DataSet

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np

# %%
#loading the dataset
df = pd.read_excel('Goal3_main.xlsx')
df.head()
# Out:
#    Goal Target Indicator   SeriesCode         SeriesDescription  GeoAreaCode  \
# 0     3    3.1     3.1.1  SH_STA_MORT  Maternal mortality ratio            4
# 1     3    3.1     3.1.1  SH_STA_MORT  Maternal mortality ratio            4
# 2     3    3.1     3.1.1  SH_STA_MORT  Maternal mortality ratio            4
# 3     3    3.1     3.1.1  SH_STA_MORT  Maternal mortality ratio            4
# 4     3    3.1     3.1.1  SH_STA_MORT  Maternal mortality ratio            4
#
#    GeoAreaName  TimePeriod       Value  Time_Detail  ...  Age  Freq  \
# 0  Afghanistan        2000  1346.14410         2000  ...  NaN   NaN
# 1  Afghanistan        2001  1273.43134         2001  ...  NaN   NaN
# 2  Afghanistan        2002  1277.30797         2002  ...  NaN   NaN
# 3  Afghanistan        2003  1196.09069         2003  ...  NaN   NaN
# 4  Afghanistan        2004  1114.88723         2004  ...  NaN   NaN
#
#    IHR Capacity  Location Nature  Observation Status Reporting Type     Sex  \
# 0           NaN       NaN      E                 NaN              G  FEMALE
# 1           NaN       NaN      E                 NaN              G  FEMALE
# 2           NaN       NaN      E                 NaN              G  FEMALE
# 3           NaN       NaN      E                 NaN              G  FEMALE
# 4           NaN       NaN      E                 NaN              G  FEMALE
#
#    Type of occupation                   Units
# 0                 NaN  PER_100000_LIVE_BIRTHS
# 1                 NaN  PER_100000_LIVE_BIRTHS
# 2                 NaN  PER_100000_LIVE_BIRTHS
# 3                 NaN  PER_100000_LIVE_BIRTHS
# 4                 NaN  PER_100000_LIVE_BIRTHS
#
# [5 rows x 27 columns]

# %%
# checking for data shape
df.shape
# Out:
# (148826, 27)

# %%
len(df['GeoAreaName'].unique())
# Out:
# 236

# %%
# checking for data features
df.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'TimePeriod', 'Value', 'Time_Detail',
#        'TimeCoverage', 'UpperBound', 'LowerBound', 'BasePeriod', 'Source',
#        'GeoInfoUrl', 'FootNote', 'Age', 'Freq', 'IHR Capacity', 'Location',
#        'Nature', 'Observation Status', 'Reporting Type', 'Sex',
#        'Type of occupation', 'Units'],
#       dtype='object')

# %%
#checking for unique SDG3 indicators avaliable in the dataset
df['Indicator'].unique()
# Out:
# array(['3.1.1', '3.2.1', '3.2.2', '3.3.1', '3.3.2', '3.7.2', '3.c.1',
#        '3.d.1'], dtype=object)

# %% [markdown]
# # Formatting the dataset to extract required features

# %%
df = df[['Goal', 'Indicator', 'GeoAreaName', 'TimePeriod', 'Value']]
df.head()
# Out:
#    Goal Indicator  GeoAreaName  TimePeriod       Value
# 0     3     3.1.1  Afghanistan        2000  1346.14410
# 1     3     3.1.1  Afghanistan        2001  1273.43134
# 2     3     3.1.1  Afghanistan        2002  1277.30797
# 3     3     3.1.1  Afghanistan        2003  1196.09069
# 4     3     3.1.1  Afghanistan        2004  1114.88723

# %%
df

# %%
# Renaming columns for easy understanding
import warnings


column_name_changes = {'GeoAreaName':'country', 'TimePeriod':'year' }
df.rename(columns=column_name_changes, inplace=True)
df.head()
# Out:
#    Goal Indicator      country  year       Value
# 0     3     3.1.1  Afghanistan  2000  1346.14410
# 1     3     3.1.1  Afghanistan  2001  1273.43134
# 2     3     3.1.1  Afghanistan  2002  1277.30797
# 3     3     3.1.1  Afghanistan  2003  1196.09069
# 4     3     3.1.1  Afghanistan  2004  1114.88723

# %%
#arrange the coulmns
col = ['country', 'Goal', 'Indicator', 'year', 'Value']
df = df[col]
df.head()
# Out:
#        country  Goal Indicator  year       Value
# 0  Afghanistan     3     3.1.1  2000  1346.14410
# 1  Afghanistan     3     3.1.1  2001  1273.43134
# 2  Afghanistan     3     3.1.1  2002  1277.30797
# 3  Afghanistan     3     3.1.1  2003  1196.09069
# 4  Afghanistan     3     3.1.1  2004  1114.88723

# %%
df.shape
# Out:
# (148826, 5)

# %%
# Renaming the indicator for ease of understanding
value_replacements = {'3.1.1':'Indicator 3.1.1: Maternal mortality ratio',
                       '3.2.1':'Indicator 3.2.1: Under-5 mortality rate', 
                      '3.2.2':'Indicator 3.2.2: Neonatal mortality rate', 
                      '3.3.1':'Indicator 3.3.1: Number of new HIV infections', 
                      '3.3.2':'Indicator 3.3.2: Tuberculosis incidence', 
                      '3.7.2':'Indicator 3.7.2: Adolescent birth rate', 
                      '3.c.1':'Indicator 3.c.1: Health worker density and distribution', 
                      '3.d.1':'Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness'}

df['Indicator'].replace(value_replacements, inplace=True)
df.head()
# Out:
#        country  Goal                                  Indicator  year  \
# 0  Afghanistan     3  Indicator 3.1.1: Maternal mortality ratio  2000
# 1  Afghanistan     3  Indicator 3.1.1: Maternal mortality ratio  2001
# 2  Afghanistan     3  Indicator 3.1.1: Maternal mortality ratio  2002
# 3  Afghanistan     3  Indicator 3.1.1: Maternal mortality ratio  2003
# 4  Afghanistan     3  Indicator 3.1.1: Maternal mortality ratio  2004
#
#         Value
# 0  1346.14410
# 1  1273.43134
# 2  1277.30797
# 3  1196.09069
# 4  1114.88723

# %%
# changing the data format from long to spread format with indicators as columns

df_pivot = df.pivot_table(index = ['country','Goal', 'year' ], columns = 'Indicator', values = 'Value')
df_pivot = df_pivot.reset_index()
df_pivot.columns.name = None
df_pivot.head()
# Out:
#        country  Goal  year  Indicator 3.1.1: Maternal mortality ratio  \
# 0  Afghanistan     3  2000                                 1346.14410
# 1  Afghanistan     3  2001                                 1273.43134
# 2  Afghanistan     3  2002                                 1277.30797
# 3  Afghanistan     3  2003                                 1196.09069
# 4  Afghanistan     3  2004                                 1114.88723
#
#    Indicator 3.2.1: Under-5 mortality rate  \
# 0                             35107.933333
# 1                             34236.125000
# 2                             33093.283333
# 3                             33393.091667
# 4                             33858.700000
#
#    Indicator 3.2.2: Neonatal mortality rate  \
# 0                                  30334.50
# 1                                  28948.35
# 2                                  28666.25
# 3                                  30338.10
# 4                                  30622.95
#
#    Indicator 3.3.1: Number of new HIV infections  \
# 0                                       0.016949
# 1                                       0.018097
# 2                                       0.019978
# 3                                       0.020338
# 4                                       0.020914
#
#    Indicator 3.3.2: Tuberculosis incidence  \
# 0                                    190.0
# 1                                    189.0
# 2                                    189.0
# 3                                    189.0
# 4                                    189.0
#
#    Indicator 3.7.2: Adolescent birth rate  \
# 0                                  182.45
# 1                                  167.22
# 2                                     NaN
# 3                                   80.45
# 4                                  135.82
#
#    Indicator 3.c.1: Health worker density and distribution  \
# 0                                                NaN
# 1                                              1.175
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_pivot.shape
# Out:
# (5107, 11)

# %% [markdown]
# # Loading the continent dataset

# %%
df_cont_1 = pd.read_csv("/Users/AKB_CIM/Documents/contintents_data/continents-according-to-our-world-in-data.csv")
df_cont_1.head()
# Out:
#                   Entity      Code  Year Continent
# 0               Abkhazia  OWID_ABK  2015      Asia
# 1            Afghanistan       AFG  2015      Asia
# 2  Akrotiri and Dhekelia  OWID_AKD  2015      Asia
# 3          Aland Islands       ALA  2015    Europe
# 4                Albania       ALB  2015    Europe

# %%
#extract only the country and continent columns

df_main = df_cont_1.drop(columns=['Code', 'Year'], axis=True)
df_main.head()
# Out:
#                   Entity Continent
# 0               Abkhazia      Asia
# 1            Afghanistan      Asia
# 2  Akrotiri and Dhekelia      Asia
# 3          Aland Islands    Europe
# 4                Albania    Europe

# %%
#rename Entity column

df_main.rename(columns={'Entity' : 'country'}, inplace=True)
df_main.head()
# Out:
#                  country Continent
# 0               Abkhazia      Asia
# 1            Afghanistan      Asia
# 2  Akrotiri and Dhekelia      Asia
# 3          Aland Islands    Europe
# 4                Albania    Europe

# %% [markdown]
# ### Merging the SDG3 dataset with Continents

# %%
df_join = pd.merge(df_pivot, df_main, on='country', how='inner')
df_join.head()
# Out:
#        country  Goal  year  Indicator 3.1.1: Maternal mortality ratio  \
# 0  Afghanistan     3  2000                                 1346.14410
# 1  Afghanistan     3  2001                                 1273.43134
# 2  Afghanistan     3  2002                                 1277.30797
# 3  Afghanistan     3  2003                                 1196.09069
# 4  Afghanistan     3  2004                                 1114.88723
#
#    Indicator 3.2.1: Under-5 mortality rate  \
# 0                             35107.933333
# 1                             34236.125000
# 2                             33093.283333
# 3                             33393.091667
# 4                             33858.700000
#
#    Indicator 3.2.2: Neonatal mortality rate  \
# 0                                  30334.50
# 1                                  28948.35
# 2                                  28666.25
# 3                                  30338.10
# 4                                  30622.95
#
#    Indicator 3.3.1: Number of new HIV infections  \
# 0                                       0.016949
# 1                                       0.018097
# 2                                       0.019978
# 3                                       0.020338
# 4                                       0.020914
#
#    Indicator 3.3.2: Tuberculosis incidence  \
# 0                                    190.0
# 1                                    189.0
# 2                                    189.0
# 3                                    189.0
# 4                                    189.0
#
#    Indicator 3.7.2: Adolescent birth rate  \
# 0                                  182.45
# 1                                  167.22
# 2                                     NaN
# 3                                   80.45
# 4                                  135.82
#
#    Indicator 3.c.1: Health worker density and distribution  \
# 0                                                NaN
# 1                                              1.175
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4      Asia

# %%
df_join.columns
# Out:
# Index(['country', 'Goal', 'year', 'Indicator 3.1.1: Maternal mortality ratio',
#        'Indicator 3.2.1: Under-5 mortality rate',
#        'Indicator 3.2.2: Neonatal mortality rate',
#        'Indicator 3.3.1: Number of new HIV infections',
#        'Indicator 3.3.2: Tuberculosis incidence',
#        'Indicator 3.7.2: Adolescent birth rate',
#        'Indicator 3.c.1: Health worker density and distribution',
#        'Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness',
#        'Continent'],
#       dtype='object')

# %%
#arrange the coulmns
coln = ['Continent','country', 'Goal', 'year', 'Indicator 3.1.1: Maternal mortality ratio',
       'Indicator 3.2.1: Under-5 mortality rate',
       'Indicator 3.2.2: Neonatal mortality rate',
       'Indicator 3.3.1: Number of new HIV infections',
       'Indicator 3.3.2: Tuberculosis incidence',
       'Indicator 3.7.2: Adolescent birth rate',
       'Indicator 3.c.1: Health worker density and distribution',
       'Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness',]

df_sdg3 = df_join[coln]
df_sdg3.head()
# Out:
#   Continent      country  Goal  year  \
# 0      Asia  Afghanistan     3  2000
# 1      Asia  Afghanistan     3  2001
# 2      Asia  Afghanistan     3  2002
# 3      Asia  Afghanistan     3  2003
# 4      Asia  Afghanistan     3  2004
#
#    Indicator 3.1.1: Maternal mortality ratio  \
# 0                                 1346.14410
# 1                                 1273.43134
# 2                                 1277.30797
# 3                                 1196.09069
# 4                                 1114.88723
#
#    Indicator 3.2.1: Under-5 mortality rate  \
# 0                             35107.933333
# 1                             34236.125000
# 2                             33093.283333
# 3                             33393.091667
# 4                             33858.700000
#
#    Indicator 3.2.2: Neonatal mortality rate  \
# 0                                  30334.50
# 1                                  28948.35
# 2                                  28666.25
# 3                                  30338.10
# 4                                  30622.95
#
#    Indicator 3.3.1: Number of new HIV infections  \
# 0                                       0.016949
# 1                                       0.018097
# 2                                       0.019978
# 3                                       0.020338
# 4                                       0.020914
#
#    Indicator 3.3.2: Tuberculosis incidence  \
# 0                                    190.0
# 1                                    189.0
# 2                                    189.0
# 3                                    189.0
# 4                                    189.0
#
#    Indicator 3.7.2: Adolescent birth rate  \
# 0                                  182.45
# 1                                  167.22
# 2                                     NaN
# 3                                   80.45
# 4                                  135.82
#
#    Indicator 3.c.1: Health worker density and distribution  \
# 0                                                NaN
# 1                                              1.175
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_sdg3.dtypes
# Out:
# Continent                                                                                             object
# country                                                                                               object
# Goal                                                                                                   int64
# year                                                                                                   int64
# Indicator 3.1.1: Maternal mortality ratio                                                            float64
# Indicator 3.2.1: Under-5 mortality rate                                                              float64
# Indicator 3.2.2: Neonatal mortality rate                                                             float64
# Indicator 3.3.1: Number of new HIV infections                                                        float64
# Indicator 3.3.2: Tuberculosis incidence                                                              float64
# Indicator 3.7.2: Adolescent birth rate                                                               float64
# Indicator 3.c.1: Health worker density and distribution                                              float64
# Indicator 3.d.1: International Health Regulations(IHR) capacity and health emergency preparedness    float64
# dtype: object

# %%
df_sdg3.shape
# Out:
# (4465, 12)

# %%
# save the formatted dataset

df_sdg3.to_csv('Formatted_SGD3_data.csv', index=False)
